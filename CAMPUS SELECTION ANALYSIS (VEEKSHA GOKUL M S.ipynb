# %% [markdown]
# VEEKSHA GOKUL M *S*

# %% [markdown]
# **CAMPUS SELECTION PREDICTION USING MACHINE** **LEARNING**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#load the dataset
df = pd.read_csv('/content/archive (1).zip')
df.head().style.set_properties(**{"background-color": "#ff4654","color": "black","border-color": "black"})
# Out:
# <style  type="text/css" >
# #T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col0,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col1,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col2,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col3,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col4,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col5,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col6,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col7,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col8,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col9,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col10,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col11,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col12,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col13,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col14,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col0,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col1,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col2,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col3,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col4,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col5,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col6,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col7,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col8,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col9,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col10,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col11,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col12,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col13,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col14,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row2_col0,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row2_col1,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row2_col2,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row2_col3,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row2_col4,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row2_col5,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row2_col6,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row2_col7,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row2_col8,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row2_col9,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row2_col10,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row2_col11,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row2_col12,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row2_col13,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row2_col14,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row3_col0,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row3_col1,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row3_col2,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row3_col3,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row3_col4,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row3_col5,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row3_col6,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row3_col7,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row3_col8,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row3_col9,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row3_col10,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row3_col11,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row3_col12,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row3_col13,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row3_col14,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row4_col0,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row4_col1,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row4_col2,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row4_col3,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row4_col4,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row4_col5,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row4_col6,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row4_col7,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row4_col8,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row4_col9,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row4_col10,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row4_col11,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row4_col12,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row4_col13,#T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row4_col14{
#             background-color:  #ff4654;
#             color:  black;
#             border-color:  black;
#         }</style><table id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002" class="dataframe"><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >sl_no</th>        <th class="col_heading level0 col1" >gender</th>        <th class="col_heading level0 col2" >ssc_p</th>        <th class="col_heading level0 col3" >ssc_b</th>        <th class="col_heading level0 col4" >hsc_p</th>        <th class="col_heading level0 col5" >hsc_b</th>        <th class="col_heading level0 col6" >hsc_s</th>        <th class="col_heading level0 col7" >degree_p</th>        <th class="col_heading level0 col8" >degree_t</th>        <th class="col_heading level0 col9" >workex</th>        <th class="col_heading level0 col10" >etest_p</th>        <th class="col_heading level0 col11" >specialisation</th>        <th class="col_heading level0 col12" >mba_p</th>        <th class="col_heading level0 col13" >status</th>        <th class="col_heading level0 col14" >salary</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col0" class="data row0 col0" >1</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col1" class="data row0 col1" >M</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col2" class="data row0 col2" >67.000000</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col3" class="data row0 col3" >Others</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col4" class="data row0 col4" >91.000000</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col5" class="data row0 col5" >Others</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col6" class="data row0 col6" >Commerce</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col7" class="data row0 col7" >58.000000</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col8" class="data row0 col8" >Sci&Tech</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col9" class="data row0 col9" >No</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col10" class="data row0 col10" >55.000000</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col11" class="data row0 col11" >Mkt&HR</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col12" class="data row0 col12" >58.800000</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col13" class="data row0 col13" >Placed</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row0_col14" class="data row0 col14" >270000.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col0" class="data row1 col0" >2</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col1" class="data row1 col1" >M</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col2" class="data row1 col2" >79.330000</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col3" class="data row1 col3" >Central</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col4" class="data row1 col4" >78.330000</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col5" class="data row1 col5" >Others</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col6" class="data row1 col6" >Science</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col7" class="data row1 col7" >77.480000</td>
#                         <td id="T_b78ab994_4f6e_11ec_8d2d_0242ac1c0002row1_col8" class="data row1 col8" >Sci&Tech</td>

# %%
df.shape
# Out:
# (215, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
plt.figure(figsize=(10,5))
sns.countplot('gender',data = df)
plt.title("Distribution of Males and Females in our Data",fontsize = 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribution of Males and Females in our Data')

# %%
plt.figure(figsize=(10,5))
sns.countplot('hsc_s',data = df)
plt.title("Distribution of the Streams that students chose in High school",fontsize = 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribution of the Streams that students chose in High school')

# %%
plt.figure(figsize=(10,5))
sns.countplot('degree_t',data = df)
plt.title("Distribution of the Type of College Degrees",fontsize = 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribution of the Type of College Degrees')

# %%
plt.figure(figsize=(10,5))
sns.countplot('workex',data = df,)
plt.title("Distribution of how many students have prior work experience",fontsize = 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribution of how many students have prior work experience')

# %%
plt.figure(figsize=(10,5))
sns.countplot('specialisation',data = df)
plt.title("Distribution of the Types of Specialisation",fontsize = 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribution of the Types of Specialisation')

# %%
plt.figure(figsize=(10,5))
sns.countplot('status',data = df,palette = 'inferno')
plt.title("Distribution of the Placements",fontsize = 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribution of the Placements')

# %%
plt.figure(figsize=(10,5))
sns.countplot('gender',data = df,hue = 'status')
plt.title("Distribution of Placements in Males and Females",fontsize = 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribution of Placements in Males and Females')

# %%
plt.figure(figsize=(10,5))
sns.countplot('workex',data = df,hue = 'status')
plt.title("Distribution of Placements in Males and Females",fontsize = 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Distribution of Placements in Males and Females')

# %%
plt.figure(figsize=(10,5))
sns.boxplot('status','mba_p',data = df)
plt.title("Relation between the Students that were placed and their score during MBA",fontsize = 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Relation between the Students that were placed and their score during MBA')

# %%
plt.figure(figsize=(10,5))
sns.boxplot('status','degree_p',data = df)
plt.title("Relation between the Students that were placed and their degree percentage",fontsize = 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Relation between the Students that were placed and their degree percentage')

# %%
plt.figure(figsize=(10,5))
sns.countplot('degree_t',data = df,hue = 'status')
plt.title("Relation between the degree types that students chose and their placement",fontsize = 15)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Relation between the degree types that students chose and their placement')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix ,accuracy_score,recall_score,precision_score

# %% [markdown]
# ENCODING

# %%
df1 = df.copy()

# %%
df1['status']= df1['status'].map({'Placed':1,'Not Placed':0})
df1['workex']= df1['workex'].map({'Yes':1,'No':0})
df1['gender']= df1['gender'].map({'M':1,'F':0})
df1['hsc_b']= df1['hsc_b'].map({'Central':1,'Others':0})
df1['ssc_b']= df1['ssc_b'].map({'Central':1,'Others':0})
df1['degree_t']= df1['degree_t'].map({'Sci&Tech':0,'Comm&Mgmt':1,'Others':2})
df1['specialisation']= df1['specialisation'].map({'Mkt&HR':1,'Mkt&Fin':0})
df1['hsc_s']= df1['hsc_s'].map({'Commerce':0,'Science':1,'Arts':2})

# %%
df1.head()
# Out:
#    gender  ssc_p  ssc_b  hsc_p  ...  specialisation  mba_p  status    salary
# 0       1  67.00      0  91.00  ...               1  58.80       1  270000.0
# 1       1  79.33      1  78.33  ...               0  66.28       1  200000.0
# 2       1  65.00      1  68.00  ...               0  57.80       1  250000.0
# 3       1  56.00      1  52.00  ...               1  59.43       0       0.0
# 4       1  85.80      1  73.60  ...               0  55.50       1  425000.0
#
# [5 rows x 14 columns]

# %% [markdown]
# TRAIN TEST SPLIT

# %%
#separating our target column and the predictor columns
X = df1[['ssc_p','hsc_p','degree_p','workex','mba_p','etest_p','gender','degree_t','specialisation']]
y = df1['status']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 101)

# %%
#we are scaling down our features so that we can get a higher accuracy and better results
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# Logistic **Regression**

# %%
lr = LogisticRegression()
lr.fit(X_train,y_train)
pred = lr.predict(X_test)

# %%
print("Accuracy:",accuracy_score(y_test, pred)*100)
print("Precision:",precision_score(y_test, pred)*100)
print("Recall:",recall_score(y_test, pred)*100)
# Out:
# Accuracy: 88.37209302325581
# Precision: 89.28571428571429
# Recall: 92.5925925925926

# %%
cm = confusion_matrix(y_test, pred)
print(cm)
# Out:
# [[13  3]
#  [ 2 25]]

# %%
tn, fp, fn, tp = confusion_matrix(y_test, pred).ravel()
sens = tp/(tp+fn)
spec = tn/(tn+fp)

print(f"True Positive Rate: ", 100*sens)
print(f"True Negative Rate: ", 100*spec)
# Out:
# True Positive Rate:  92.5925925925926
# True Negative Rate:  81.25

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score

fpr, tpr, thresholds = roc_curve(y_test, pred)
auc = roc_auc_score(y_test, pred)
print('AUC: %.3f' % auc)
# Out:
# AUC: 0.869

# %%
plt.figure()
plt.title('ROC for Logistic regression')
plt.plot(fpr, tpr, color='darkorange',marker='.',
         lw=2, label='ROC curve (area = %0.2f)')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# **SVM** **CLASSIFIER**

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train,y_train)
svc_pred = svc.predict(X_test)
print("Accuracy:",accuracy_score(y_test, svc_pred)*100)
print("Precision:",precision_score(y_test, svc_pred)*100)
print("Recall:",recall_score(y_test, svc_pred)*100)
# Out:
# Accuracy: 79.06976744186046
# Precision: 82.14285714285714
# Recall: 85.18518518518519

# %%
cm = confusion_matrix(y_test, svc_pred)
print(cm)
[[11  5]
 [ 4 23]]
from sklearn.metrics import roc_curve, auc, roc_auc_score

fpr, tpr, thresholds = roc_curve(y_test, svc_pred)
auc = roc_auc_score(y_test, svc_pred)
print('AUC: %.3f' % auc)
# Out:
#   File "<ipython-input-43-bd9d5eac3159>", line 3
#     [[11  5]
#           ^
# SyntaxError: invalid syntax

# %%
plt.figure()
plt.title('ROC for SVM with linear kernel')
plt.plot(fpr, tpr, color='darkorange',marker='.',
         lw=2, label='ROC curve (area = %0.2f)')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# PLOYNOMIAL KERNEL

# %%
svclassifier = SVC(kernel='poly', degree=8)
svclassifier.fit(X_train, y_train)
SVC(degree=8, kernel='poly')
y_pred = svclassifier.predict(X_test)
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[ 5 11]
#  [ 2 25]]
#               precision    recall  f1-score   support
#
#            0       0.71      0.31      0.43        16
#            1       0.69      0.93      0.79        27
#
#     accuracy                           0.70        43
#    macro avg       0.70      0.62      0.61        43
# weighted avg       0.70      0.70      0.66        43

# %%
from sklearn.metrics import roc_curve, auc, roc_auc_score

fpr, tpr, thresholds = roc_curve(y_test, y_pred)
auc = roc_auc_score(y_test, y_pred)
print('AUC: %.3f' % auc)
plt.figure()
plt.title('ROC for SVM with polynomial kernel')
plt.plot(fpr, tpr, color='darkorange',marker='.',
         lw=2, label='ROC curve (area = %0.2f)')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend(loc="lower right")
plt.show()
# Out:
# AUC: 0.619
